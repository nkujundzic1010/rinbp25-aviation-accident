# %% [markdown]
# <div align="center">
#
# | <h1> **Aviation Accident Network Analysis** </h1> |
# ---
#
# ## *Nediljka Kujundžić*

# %% [markdown]
# ##Web scraping

# %%
# !pip install beautifulsoup4 requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
from datetime import datetime
import urllib.parse

def scrape_aircraft_accidents():
    """
    Scrapes aircraft accident data directly from Wikipedia and saves to Excel file.
    Includes detailed information from each accident's specific page.
    """
    # URL glavne stranice s popisom nesreća
    main_url = "https://en.wikipedia.org/wiki/List_of_accidents_and_incidents_involving_commercial_aircraft"
    base_url = "https://en.wikipedia.org"

    print("Dohvaćam glavnu stranicu...")
    response = requests.get(main_url)
    main_soup = BeautifulSoup(response.text, 'html.parser')

    # Pronalazi sve linkove na godine (u sadržaju)
    toc = main_soup.find('div', {'id': 'toc'})

    # Alternativni način ako TOC nije dostupan
    if not toc:
        print("Traženje godina u tekstu...")
        # Pronađi sve naslove koji su godine
        year_headings = main_soup.find_all(['h2', 'h3', 'h4'], id=re.compile(r'^\d{4}$'))
        year_links = []
        for heading in year_headings:
            if heading.get('id') and heading.get('id').isdigit() and 1900 <= int(heading.get('id')) <= 2025:
                year_links.append({'year': heading.get('id'), 'href': f"#{heading.get('id')}"})
    else:
        # Pronađi sve linkove na godine u sadržaju
        year_links = []
        for link in toc.find_all('a'):
            href = link.get('href', '')
            text = link.get_text().strip()
            # Provjeri je li link na godinu
            if href and '#' in href and text.isdigit() and 1900 <= int(text) <= 2025:
                year_links.append({'year': text, 'href': href})

    # Sortiraj godine u padajućem redoslijedu (najnovije prvo)
    year_links.sort(key=lambda x: int(x['year']), reverse=True)

    # Uzmi samo zadnjih 25 godina
    current_year = datetime.now().year
    last_25_years = [y for y in year_links if int(y['year']) > current_year - 25]

    print(f"Pronađeno {len(year_links)} godina ukupno.")
    print(f"Obrađujem samo zadnjih 25 godina ({len(last_25_years)} godina)...")

    # Lista za spremanje podataka o nesrećama
    all_accidents = []

    # Obradi svaku godinu iz zadnjih 25 godina
    for i, year_link in enumerate(last_25_years):
        year = year_link['year']
        print(f"\nObrađujem godinu {year} ({i+1}/{len(last_25_years)})...")

        # Pronađi sekciju za tu godinu
        year_id = year_link['href'].replace('#', '')
        year_section = main_soup.find(id=year_id)

        if not year_section:
            print(f"Ne mogu pronaći sekciju za godinu {year}")
            continue

        # Pronađi sljedeći <ul> element koji sadrži listu nesreća
        accident_list = None
        current = year_section.find_next()
        while current and current.name != 'h2' and current.name != 'h3':
            if current.name == 'ul':
                accident_list = current
                break
            current = current.find_next()

        if not accident_list:
            print(f"Ne mogu pronaći listu nesreća za godinu {year}")
            continue

        # Pronađi sve stavke liste (nesreće)
        accident_items = accident_list.find_all('li')
        print(f"Pronađeno {len(accident_items)} nesreća za godinu {year}")

        # Obradi sve nesreće
        for j, item in enumerate(accident_items):
            print(f"  Obrađujem nesreću {j+1}/{len(accident_items)}")

            # Ekstrahiraj tekst nesreće
            accident_text = item.get_text()

            # Inicijaliziraj podatke o nesreći
            accident_data = {
                'year': year,
                'date': None,
                'location': None,
                'aircraft_type': None,
                'operator': None,
                'flight_origin': None,  # Preimenovano iz flight_number
                'registration': None,
                'destination': None,
                'passengers': None,
                'crew': None,
                'occupants': None,
                'injuries': None,
                'fatalities': None,
                'survivors': None,
                'missing': None,
                'summary': None
            }

            # Provjeri ima li link za detaljniju stranicu
            accident_link = item.find('a')
            if accident_link and accident_link.get('href'):
                # Dohvati stranicu specifičnu za nesreću
                detail_url = urllib.parse.urljoin(base_url, accident_link.get('href'))
                print(f"    Dohvaćam detalje sa: {detail_url}")

                try:
                    detail_response = requests.get(detail_url)
                    # Kratka pauza između zahtjeva
                    time.sleep(0.5)

                    if detail_response.status_code == 200:
                        detail_soup = BeautifulSoup(detail_response.text, 'html.parser')

                        # DODATNO: Pokušaj pronaći aircraft_type iz prvog paragrafa ako sadrži proizvođača
                        first_paragraph = detail_soup.find('p')
                        if first_paragraph:
                            para_text = first_paragraph.get_text()
                            # Provjeri sadrži li paragraf informacije o avionu
                            aircraft_manufacturers = ['Boeing', 'Airbus', 'McDonnell Douglas', 'Embraer',
                                                    'Fokker', 'Cessna', 'Bombardier', 'ATR', 'Tupolev',
                                                    'Ilyushin', 'Antonov', 'Sukhoi', 'Lockheed', 'BAe',
                                                    'De Havilland', 'Concorde', 'Saab', 'Yakovlev', 'Dornier']

                            # Traži prvi proizvođač koji se spominje u paragrafu
                            for manufacturer in aircraft_manufacturers:
                                if manufacturer in para_text:
                                    # Pronađi puni naziv modela (do 30 znakova nakon imena proizvođača)
                                    model_regex = f"({manufacturer}\\s+[\\w\\d\\-\\.\\s]{{1,30}}?)(?:\\s|,|\\.|\\(|was)"
                                    model_match = re.search(model_regex, para_text)
                                    if model_match:
                                        # Očisti rezultat
                                        aircraft_type = model_match.group(1).strip()
                                        # Skrati na razumnu duljinu ako je predugo
                                        if len(aircraft_type) > 50:
                                            aircraft_type = aircraft_type[:50]
                                        accident_data['aircraft_type'] = aircraft_type
                                        break

                        # Pronađi info tablicu (obično ima klasu 'infobox')
                        info_table = detail_soup.find('table', {'class': ['infobox', 'vcard']})

                        if info_table:
                            print("    Pronađena info tablica!")
                            # Pronađi sve redove tablice
                            rows = info_table.find_all('tr')

                            for row in rows:
                                # Pronađi zaglavlje i vrijednost
                                header = row.find('th')
                                value = row.find('td')

                                if header and value:
                                    header_text = header.get_text().strip()
                                    value_text = value.get_text().strip()

                                    # Mapiraj polja iz tablice na naša polja
                                    if 'Date' in header_text:
                                        accident_data['date'] = value_text
                                    elif 'Site' in header_text:
                                        accident_data['location'] = value_text
                                    # OVDJE JE PROMJENA: Dodali smo 'Type' kao jedan od mogućih naziva stupca
                                    elif any(s in header_text for s in ['Aircraft type', 'Aircraft', 'Type']):
                                        accident_data['aircraft_type'] = value_text
                                    elif 'Operator' in header_text:
                                        accident_data['operator'] = value_text
                                    elif 'Flight' in header_text or 'flight No' in header_text:
                                        accident_data['flight_origin'] = value_text  # Preimenovano
                                    elif 'Registration' in header_text:
                                        accident_data['registration'] = value_text
                                    elif 'Destination' in header_text:
                                        accident_data['destination'] = value_text
                                    elif 'Passengers' in header_text:
                                        accident_data['passengers'] = value_text
                                    elif 'Crew' in header_text:
                                        accident_data['crew'] = value_text
                                    elif 'Occupants' in header_text:
                                        accident_data['occupants'] = value_text
                                    elif 'Injuries' in header_text:
                                        accident_data['injuries'] = value_text
                                    elif 'Fatalities' in header_text:
                                        accident_data['fatalities'] = value_text
                                    elif 'Survivors' in header_text:
                                        accident_data['survivors'] = value_text
                                    elif 'Missing' in header_text:
                                        accident_data['missing'] = value_text
                                    elif 'Summary' in header_text:
                                        accident_data['summary'] = value_text
                        else:
                            print("    Info tablica nije pronađena, koristim regularne izraze iz teksta.")
                    else:
                        print(f"    Greška pri dohvatu detalja: {detail_response.status_code}")

                except Exception as e:
                    print(f"    Greška pri obradi detaljne stranice: {e}")

            # Ako neki podaci nedostaju, pokušaj ih dobiti iz originalnog teksta nesreće
            # Ovo je korisno za slučajeve kada nisu dostupne detaljne stranice

            # Pokušaj pronaći datum ako još nije pronađen
            if not accident_data['date']:
                date_match = re.search(r'(\d{1,2}\s+\w+|\w+\s+\d{1,2}),?\s+\d{4}', accident_text)
                if date_match:
                    accident_data['date'] = date_match.group(0)

            # Pokušaj pronaći lokaciju ako još nije pronađena
            if not accident_data['location']:
                location_patterns = [
                    r'near ([^\.]+)',
                    r'at ([^\.]+) Airport',
                    r'in ([^\.]+?)(?: when| after| while)'
                ]
                for pattern in location_patterns:
                    location_match = re.search(pattern, accident_text, re.IGNORECASE)
                    if location_match:
                        accident_data['location'] = location_match.group(1).strip()
                        break

            # Pokušaj pronaći aviokompaniju ako još nije pronađena
            if not accident_data['operator']:
                airline_patterns = [
                    r'([A-Za-z\s]+) Flight',
                    r'operated by ([A-Za-z\s]+)',
                    r'([A-Za-z\s]+) Airlines'
                ]
                for pattern in airline_patterns:
                    airline_match = re.search(pattern, accident_text, re.IGNORECASE)
                    if airline_match:
                        operator = airline_match.group(1).strip()
                        # Očisti nepotrebne riječi
                        operator = re.sub(r'\b(flight|operated|by)\b', '', operator, flags=re.IGNORECASE).strip()
                        accident_data['operator'] = operator
                        break

            # Pokušaj pronaći model aviona ako još nije pronađen
            if not accident_data['aircraft_type']:
                # Prošireni popis obrazaca za pronalaženje modela aviona
                model_patterns = [
                    # Standardni proizvođači
                    r'(Boeing \d{3}(?:-\d+)?)',
                    r'(Airbus A\d{3}(?:-\d+)?)',
                    r'(McDonnell Douglas [A-Z0-9\-]+)',
                    r'(Douglas [A-Z0-9\-]+)',
                    r'(Embraer [A-Z0-9\-]+)',
                    r'(Bombardier [A-Z0-9\-]+)',
                    r'(Canadair [A-Z0-9\-]+)',
                    r'(ATR (?:\d{2}(?:-\d+)?))',
                    r'(Fokker [A-Z0-9\-]+)',
                    r'(Cessna [A-Z0-9\-]+)',
                    # Ruski/sovjetski proizvođači
                    r'(Tupolev Tu-\d+)',
                    r'(Ilyushin Il-\d+)',
                    r'(Antonov An-\d+)',
                    r'(Sukhoi [A-Z0-9\-]+)',
                    # Drugi važni proizvođači
                    r'(Lockheed [A-Z0-9\-]+)',
                    r'(BAe [A-Z0-9\-]+)',
                    r'(British Aerospace [A-Z0-9\-]+)',
                    r'(De Havilland [A-Z0-9\-]+)',
                    r'(Saab [A-Z0-9\-]+)',
                    r'(Yakovlev [A-Z0-9\-]+)',
                    r'(Dornier [A-Z0-9\-]+)',
                    r'(Concorde)',
                    # Opći obrasci za hvatanje modela koji možda nisu specifično navedeni
                    r'aircraft (?:type|was)? (?:a|an) ([A-Za-z\-]+ [A-Za-z0-9\-]+)',
                    r'([A-Za-z]+ [A-Za-z0-9\-]+ aircraft)',
                    r'flight was (?:operated by )?(?:a|an) ([A-Za-z\-]+ [A-Za-z0-9\-]+)'
                ]

                for pattern in model_patterns:
                    model_match = re.search(pattern, accident_text, re.IGNORECASE)
                    if model_match:
                        model = model_match.group(1).strip()
                        # Očisti nepotrebne riječi
                        model = re.sub(r'\baircraft\b', '', model, flags=re.IGNORECASE).strip()
                        accident_data['aircraft_type'] = model
                        break

            # Dodaj nesreću u listu
            all_accidents.append(accident_data)

    # Kreiraj DataFrame iz prikupljenih podataka
    df = pd.DataFrame(all_accidents)

    # Ispiši statistiku o popunjenosti
    total_rows = len(df)
    aircraft_filled = df['aircraft_type'].notna().sum()
    percentage = (aircraft_filled / total_rows * 100) if total_rows > 0 else 0
    print(f"\nStatistika popunjenosti aircraft_type: {aircraft_filled}/{total_rows} ({percentage:.1f}%)")

    # Generiraj timestamp za nazive datoteka
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

    # Spremi u Excel datoteku
    excel_filename = f'aircraft_accidents.xlsx'
    df.to_excel(excel_filename, index=False)
    print(f"\nPodaci uspješno spremljeni u {excel_filename}")

    # Spremi u CSV datoteku
    csv_filename = f'aircraft_accidents.csv'
    df.to_csv(csv_filename, index=False, encoding='utf-8')
    print(f"Podaci uspješno spremljeni u {csv_filename}")

    # Za Google Colab, omogući preuzimanje
    try:
        from google.colab import files
        print(f"Preuzimam Excel datoteku {excel_filename}...")
        files.download(excel_filename)
        print(f"Preuzimam CSV datoteku {csv_filename}...")
        files.download(csv_filename)
    except ImportError:
        print("Google Colab nije detektiran. Preuzimanje datoteke neće biti dostupno.")

    return df

if __name__ == "__main__":
    # Instaliraj potrebne pakete
    try:
        import pandas
        import bs4
        import urllib.parse
    except ImportError:
        print("Instaliram potrebne pakete...")
        import sys
        import subprocess
        subprocess.check_call([sys.executable, "-m", "pip", "install", "pandas", "beautifulsoup4", "requests", "openpyxl"])

    # Pokreni scraping
    df = scrape_aircraft_accidents()

    # Prikaži prvih 10 redova podataka
    print("\nPrvih 10 redova prikupljenih podataka:")
    print(df.head(10))
# Out:
# Dohvaćam glavnu stranicu...
# Traženje godina u tekstu...
# Pronađeno 105 godina ukupno.
# Obrađujem samo zadnjih 25 godina (25 godina)...
#
# Obrađujem godinu 2025 (1/25)...
# Pronađeno 7 nesreća za godinu 2025
#   Obrađujem nesreću 1/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_Busan_Flight_391
#     Pronađena info tablica!
#   Obrađujem nesreću 2/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2025_Light_Air_Services_Beechcraft_1900_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 3/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2025_Potomac_River_mid-air_collision
#     Pronađena info tablica!
#   Obrađujem nesreću 4/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Bering_Air_Flight_445
#     Pronađena info tablica!
#   Obrađujem nesreću 5/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Delta_Connection_Flight_4819
#     Pronađena info tablica!
#   Obrađujem nesreću 6/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Aerol%C3%ADnea_Lanhsa_Flight_018
#     Pronađena info tablica!
#   Obrađujem nesreću 7/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2025_Trident_Aviation_DHC-5_crash
#     Pronađena info tablica!
#
# Obrađujem godinu 2024 (2/25)...
# Pronađeno 7 nesreća za godinu 2024
#   Obrađujem nesreću 1/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2024_Haneda_Airport_runway_collision
#     Pronađena info tablica!
#   Obrađujem nesreću 2/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Alaska_Airlines_Flight_1282
#     Pronađena info tablica!
#   Obrađujem nesreću 3/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Northwestern_Air_Flight_738
#     Pronađena info tablica!
#   Obrađujem nesreću 4/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_Serbia_Flight_324
#     Pronađena info tablica!
#   Obrađujem nesreću 5/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Safarilink_Aviation_Flight_053
#     Pronađena info tablica!
#   Obrađujem nesreću 6/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/LATAM_Airlines_Flight_800
#     Pronađena info tablica!
#   Obrađujem nesreću 7/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Singapore_Airlines_Flight_321
#     Pronađena info tablica!
#
# Obrađujem godinu 2023 (3/25)...
# Pronađeno 1 nesreća za godinu 2023
#   Obrađujem nesreću 1/1
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2023_Gold_Coast_mid-air_collision
#     Pronađena info tablica!
#
# Obrađujem godinu 2022 (4/25)...
# Pronađeno 10 nesreća za godinu 2022
#   Obrađujem nesreću 1/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/China_Eastern_Airlines_Flight_5735
#     Pronađena info tablica!
#   Obrađujem nesreću 2/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/DHL_Aero_Expreso_Flight_7216
#     Pronađena info tablica!
#   Obrađujem nesreću 3/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Tibet_Airlines_Flight_9833
#     Pronađena info tablica!
#   Obrađujem nesreću 4/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Tara_Air_Flight_197
#     Pronađena info tablica!
#   Obrađujem nesreću 5/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/RED_Air_Flight_203
#     Pronađena info tablica!
#   Obrađujem nesreću 6/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Meridian_Flight_3032
#     Pronađena info tablica!
#   Obrađujem nesreću 7/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2022_Mutiny_Bay_DHC-3_Otter_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 8/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Korean_Air_Flight_631
#     Pronađena info tablica!
#   Obrađujem nesreću 9/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Precision_Air_Flight_494
#     Pronađena info tablica!
#   Obrađujem nesreću 10/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/LATAM_Per%C3%BA_Flight_2213
#     Pronađena info tablica!
#
# Obrađujem godinu 2021 (5/25)...
# Pronađeno 6 nesreća za godinu 2021
#   Obrađujem nesreću 1/6
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Sriwijaya_Air_Flight_182
#     Pronađena info tablica!
#   Obrađujem nesreću 2/6
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Longtail_Aviation_Flight_5504
#     Pronađena info tablica!
#   Obrađujem nesreću 3/6
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/United_Airlines_Flight_328
#     Pronađena info tablica!
#   Obrađujem nesreću 4/6
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2021_South_Sudan_Supreme_Airlines_Let_L-410_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 5/6
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2021_Centennial_Airport_mid-air_collision
#     Pronađena info tablica!
#   Obrađujem nesreću 6/6
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Ryanair_Flight_4978
#     Pronađena info tablica!
#
# Obrađujem godinu 2020 (6/25)...
# Pronađeno 2 nesreća za godinu 2020
#   Obrađujem nesreću 1/2
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Ukraine_International_Airlines_Flight_752
#     Pronađena info tablica!
#   Obrađujem nesreću 2/2
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Delta_Air_Lines_Flight_89
#     Pronađena info tablica!
#
# Obrađujem godinu 2019 (7/25)...
# Pronađeno 16 nesreća za godinu 2019
#   Obrađujem nesreću 1/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2019_Saha_Airlines_Boeing_707_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 2/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Atlas_Air_Flight_3591
#     Pronađena info tablica!
#   Obrađujem nesreću 3/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Biman_Bangladesh_Airlines_Flight_147
#     Pronađena info tablica!
#   Obrađujem nesreću 4/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/United_Express_Flight_4933
#     Pronađena info tablica!
#   Obrađujem nesreću 5/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2019_Colombia_DC-3_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 6/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Ethiopian_Airlines_Flight_302
#     Pronađena info tablica!
#   Obrađujem nesreću 7/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Miami_Air_International_Flight_293
#     Pronađena info tablica!
#   Obrađujem nesreću 8/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Aeroflot_Flight_1492
#     Pronađena info tablica!
#   Obrađujem nesreću 9/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Biman_Bangladesh_Airlines_Flight_060
#     Pronađena info tablica!
#   Obrađujem nesreću 10/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2019_Alaska_mid-air_collision
#     Pronađena info tablica!
#   Obrađujem nesreću 11/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Angara_Airlines_Flight_200
#     Pronađena info tablica!
#   Obrađujem nesreću 12/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Ural_Airlines_Flight_178
#     Pronađena info tablica!
#   Obrađujem nesreću 13/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Ukraine_Air_Alliance_Flight_4050
#     Pronađena info tablica!
#   Obrađujem nesreću 14/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/PenAir_Flight_3296
#     Pronađena info tablica!
#   Obrađujem nesreću 15/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2019_Busy_Bee_Congo_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 16/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Bek_Air_Flight_2100
#     Pronađena info tablica!
#
# Obrađujem godinu 2018 (8/25)...
# Pronađeno 5 nesreća za godinu 2018
#   Obrađujem nesreću 1/5
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Pegasus_Airlines_Flight_8622
#     Pronađena info tablica!
#   Obrađujem nesreću 2/5
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Saratov_Airlines_Flight_703
#     Pronađena info tablica!
#   Obrađujem nesreću 3/5
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/United_Airlines_Flight_1175
#     Pronađena info tablica!
#   Obrađujem nesreću 4/5
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Iran_Aseman_Airlines_Flight_3704
#     Pronađena info tablica!
#   Obrađujem nesreću 5/5
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/US-Bangla_Airlines_Flight_211
#     Pronađena info tablica!
#
# Obrađujem godinu 2017 (9/25)...
# Pronađeno 10 nesreća za godinu 2017
#   Obrađujem nesreću 1/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Turkish_Airlines_Flight_6491
#     Pronađena info tablica!
#   Obrađujem nesreću 2/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Ameristar_Charters_Flight_9363
#     Pronađena info tablica!
#   Obrađujem nesreću 3/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Peruvian_Airlines_Flight_112
#     Pronađena info tablica!
#   Obrađujem nesreću 4/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Goma_Air_Flight_409
#     Pronađena info tablica!
#   Obrađujem nesreću 5/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_Canada_Flight_759
#     Pronađena info tablica!
#   Obrađujem nesreću 6/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_France_Flight_66
#     Pronađena info tablica!
#   Obrađujem nesreću 7/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2017_Valan_International_Antonov_An-26_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 8/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Khabarovsk_Airlines_Flight_463
#     Pronađena info tablica!
#   Obrađujem nesreću 9/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/West_Wind_Aviation_Flight_282
#     Pronađena info tablica!
#   Obrađujem nesreću 10/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Nature_Air_Flight_144
#     Pronađena info tablica!
#
# Obrađujem godinu 2016 (10/25)...
# Pronađeno 24 nesreća za godinu 2016
#   Obrađujem nesreću 1/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/West_Air_Sweden_Flight_294
#     Pronađena info tablica!
#   Obrađujem nesreću 2/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Daallo_Airlines_Flight_159
#     Pronađena info tablica!
#   Obrađujem nesreću 3/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Tara_Air_Flight_193
#     Pronađena info tablica!
#   Obrađujem nesreću 4/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2016_Air_Kasthamandap_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 5/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/True_Aviation_Flight_21
#     Pronađena info tablica!
#   Obrađujem nesreću 6/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Flydubai_Flight_981
#     Pronađena info tablica!
#   Obrađujem nesreću 7/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/EgyptAir_Flight_181
#     Pronađena info tablica!
#   Obrađujem nesreću 8/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Batik_Air_Flight_7703
#     Pronađena info tablica!
#   Obrađujem nesreću 9/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2016_Sunbird_Aviation_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 10/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2016_Tur%C3%B8y_helicopter_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 11/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2016_Silk_Way_Airlines_Antonov_An-12_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 12/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/EgyptAir_Flight_804
#     Pronađena info tablica!
#   Obrađujem nesreću 13/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Korean_Air_Flight_2708
#     Pronađena info tablica!
#   Obrađujem nesreću 14/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Emirates_Flight_521
#     Pronađena info tablica!
#   Obrađujem nesreću 15/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/ASL_Airlines_Hungary_Flight_7332
#     Pronađena info tablica!
#   Obrađujem nesreću 16/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Southwest_Airlines_Flight_3472
#     Pronađena info tablica!
#   Obrađujem nesreću 17/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Skol_Airlines_Flight_9375
#     Pronađena info tablica!
#   Obrađujem nesreću 18/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/American_Airlines_Flight_383_(2016)
#     Pronađena info tablica!
#   Obrađujem nesreću 19/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/FedEx_Express_Flight_910
#     Pronađena info tablica!
#   Obrađujem nesreću 20/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2016_Alfa_Indonesia_DHC-4_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 21/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/LaMia_Flight_2933
#     Pronađena info tablica!
#   Obrađujem nesreću 22/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Pakistan_International_Airlines_Flight_661
#     Pronađena info tablica!
#   Obrađujem nesreću 23/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Aerosucre_Flight_157
#     Pronađena info tablica!
#   Obrađujem nesreću 24/24
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Afriqiyah_Airways_Flight_209
#     Pronađena info tablica!
#
# Obrađujem godinu 2015 (11/25)...
# Pronađeno 14 nesreća za godinu 2015
#   Obrađujem nesreću 1/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/TransAsia_Airways_Flight_235
#     Pronađena info tablica!
#   Obrađujem nesreću 2/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Delta_Air_Lines_Flight_1086
#     Pronađena info tablica!
#   Obrađujem nesreću 3/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Germanwings_Flight_9525
#     Pronađena info tablica!
#   Obrađujem nesreću 4/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_Canada_Flight_624
#     Pronađena info tablica!
#   Obrađujem nesreću 5/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Carson_Air_Flight_66
#     Pronađena info tablica!
#   Obrađujem nesreću 6/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Asiana_Airlines_Flight_162
#     Pronađena info tablica!
#   Obrađujem nesreću 7/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Trigana_Air_Service_Flight_267
#     Pronađena info tablica!
#   Obrađujem nesreću 8/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2015_Senegal_mid-air_collision
#     Pronađena info tablica!
#   Obrađujem nesreću 9/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/British_Airways_Flight_2276
#     Pronađena info tablica!
#   Obrađujem nesreću 10/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Aviastar_Flight_7503
#     Pronađena info tablica!
#   Obrađujem nesreću 11/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Dynamic_Airways_Flight_405
#     Pronađena info tablica!
#   Obrađujem nesreću 12/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Metrojet_Flight_9268
#     Pronađena info tablica!
#   Obrađujem nesreću 13/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2015_Juba_An-12_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 14/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Avia_Traffic_Company_Flight_768
#     Pronađena info tablica!
#
# Obrađujem godinu 2014 (12/25)...
# Pronađeno 10 nesreća za godinu 2014
#   Obrađujem nesreću 1/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Nepal_Airlines_Flight_183
#     Pronađena info tablica!
#   Obrađujem nesreću 2/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Ethiopian_Airlines_Flight_702
#     Pronađena info tablica!
#   Obrađujem nesreću 3/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Malaysia_Airlines_Flight_370
#     Pronađena info tablica!
#   Obrađujem nesreću 4/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Pakistan_International_Airlines_Flight_756
#     Pronađena info tablica!
#   Obrađujem nesreću 5/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Malaysia_Airlines_Flight_17
#     Pronađena info tablica!
#   Obrađujem nesreću 6/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/TransAsia_Airways_Flight_222
#     Pronađena info tablica!
#   Obrađujem nesreću 7/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_Alg%C3%A9rie_Flight_5017
#     Pronađena info tablica!
#   Obrađujem nesreću 8/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Sepahan_Airlines_Flight_5915
#     Pronađena info tablica!
#   Obrađujem nesreću 9/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Loganair_Flight_6780
#     Pronađena info tablica!
#   Obrađujem nesreću 10/10
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Indonesia_AirAsia_Flight_8501
#     Pronađena info tablica!
#
# Obrađujem godinu 2013 (13/25)...
# Pronađeno 5 nesreća za godinu 2013
#   Obrađujem nesreću 1/5
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2013_Transaereo_5074_Britten-Norman_Islander_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 2/5
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/SCAT_Airlines_Flight_760
#     Pronađena info tablica!
#   Obrađujem nesreću 3/5
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/South_Airlines_Flight_8971
#     Pronađena info tablica!
#   Obrađujem nesreću 4/5
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2013_Compagnie_Africaine_d%27Aviation_Fokker_50_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 5/5
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/ACE_Air_Cargo_Flight_51
#     Pronađena info tablica!
#
# Obrađujem godinu 2012 (14/25)...
# Pronađeno 2 nesreća za godinu 2012
#   Obrađujem nesreću 1/2
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2012_Katanga_Express_Gulfstream_IV_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 2/2
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/JetBlue_Flight_191
#     Pronađena info tablica!
#
# Obrađujem godinu 2011 (15/25)...
# Pronađeno 31 nesreća za godinu 2011
#   Obrađujem nesreću 1/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Kolavia_Flight_348
#     Pronađena info tablica!
#   Obrađujem nesreću 2/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Iran_Air_Flight_277
#     Pronađena info tablica!
#   Obrađujem nesreću 3/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Manx2_Flight_7100
#     Pronađena info tablica!
#   Obrađujem nesreću 4/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Central_American_Airways_Flight_731
#     Pronađena info tablica!
#   Obrađujem nesreću 5/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2011_Trans_Air_Congo_Antonov_An-12_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 6/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Southwest_Airlines_Flight_812
#     Pronađena info tablica!
#   Obrađujem nesreću 7/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Georgian_Airways_Flight_834
#     Pronađena info tablica!
#   Obrađujem nesreću 8/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2011_Pawan_Hans_Mi-17_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 9/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Merpati_Nusantara_Airlines_Flight_8968
#     Pronađena info tablica!
#   Obrađujem nesreću 10/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Sol_L%C3%ADneas_A%C3%A9reas_Flight_5428
#     Pronađena info tablica!
#   Obrađujem nesreću 11/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2011_Lightship_Europe_airship_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 12/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/RusAir_Flight_9605
#     Pronađena info tablica!
#   Obrađujem nesreću 13/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2011_Missinippi_Airways_Cessna_208_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 14/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2011_Silk_Way_Airlines_Ilyushin_Il-76_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 15/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Hewa_Bora_Airways_Flight_952
#     Pronađena info tablica!
#   Obrađujem nesreću 16/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Angara_Airlines_Flight_9007
#     Pronađena info tablica!
#   Obrađujem nesreću 17/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Noar_Linhas_A%C3%A9reas_Flight_4896
#     Pronađena info tablica!
#   Obrađujem nesreću 18/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Asiana_Airlines_Flight_991
#     Pronađena info tablica!
#   Obrađujem nesreću 19/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/EgyptAir_Flight_667
#     Pronađena info tablica!
#   Obrađujem nesreću 20/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Caribbean_Airlines_Flight_523
#     Pronađena info tablica!
#   Obrađujem nesreću 21/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Avis-Amur_Flight_9209
#     Pronađena info tablica!
#   Obrađujem nesreću 22/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/First_Air_Flight_6560
#     Pronađena info tablica!
#   Obrađujem nesreću 23/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Aerocon_Flight_238
#     Pronađena info tablica!
#   Obrađujem nesreću 24/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2011_Lokomotiv_Yaroslavl_plane_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 25/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Buddha_Air_Flight_103
#     Pronađena info tablica!
#   Obrađujem nesreću 26/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Nusantara_Buana_Air_Flight_823
#     Pronađena info tablica!
#   Obrađujem nesreću 27/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Airlines_PNG_Flight_1600
#     Pronađena info tablica!
#   Obrađujem nesreću 28/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2011_Moremi_Air_Cessna_208_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 29/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Iran_Air_Flight_742
#     Pronađena info tablica!
#   Obrađujem nesreću 30/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/LOT_Polish_Airlines_Flight_16
#     Pronađena info tablica!
#   Obrađujem nesreću 31/31
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Kyrgyzstan_Air_Company_Flight_3
#     Pronađena info tablica!
#
# Obrađujem godinu 2010 (16/25)...
# Pronađeno 7 nesreća za godinu 2010
#   Obrađujem nesreću 1/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Taban_Air_Flight_6437
#     Pronađena info tablica!
#   Obrađujem nesreću 2/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Ethiopian_Airlines_Flight_409
#     Pronađena info tablica!
#   Obrađujem nesreću 3/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Aviastar-TU_Flight_1906
#     Pronađena info tablica!
#   Obrađujem nesreću 4/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/United_Airlines_Flight_663
#     Pronađena info tablica!
#   Obrađujem nesreću 5/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/AeroUnion_Flight_302
#     Pronađena info tablica!
#   Obrađujem nesreću 6/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Merpati_Nusantara_Airlines_Flight_836
#     Pronađena info tablica!
#   Obrađujem nesreću 7/7
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Cathay_Pacific_Flight_780
#     Pronađena info tablica!
#
# Obrađujem godinu 2009 (17/25)...
# Pronađeno 30 nesreća za godinu 2009
#   Obrađujem nesreću 1/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/US_Airways_Flight_1549
#     Pronađena info tablica!
#   Obrađujem nesreću 2/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Empire_Airlines_Flight_8284
#     Pronađena info tablica!
#   Obrađujem nesreću 3/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2009_Manaus_Aerot%C3%A1xi_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 4/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Colgan_Air_Flight_3407
#     Pronađena info tablica!
#   Obrađujem nesreću 5/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Turkish_Airlines_Flight_1951
#     Pronađena info tablica!
#   Obrađujem nesreću 6/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Cougar_Helicopters_Flight_91
#     Pronađena info tablica!
#   Obrađujem nesreću 7/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Emirates_Flight_407
#     Pronađena info tablica!
#   Obrađujem nesreću 8/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/FedEx_Express_Flight_80
#     Pronađena info tablica!
#   Obrađujem nesreću 9/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Bond_Offshore_Helicopters_Flight_85N
#     Pronađena info tablica!
#   Obrađujem nesreću 10/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2009_Aviastar_British_Aerospace_146_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 11/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Mimika_Air_Flight_514
#     Pronađena info tablica!
#   Obrađujem nesreću 12/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/CanJet_Flight_918
#     Pronađena info tablica!
#   Obrađujem nesreću 13/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_France_Flight_447
#     Pronađena info tablica!
#   Obrađujem nesreću 14/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Yemenia_Flight_626
#     Pronađena info tablica!
#   Obrađujem nesreću 15/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Southwest_Airlines_Flight_2294
#     Pronađena info tablica!
#   Obrađujem nesreću 16/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Caspian_Airlines_Flight_7908
#     Pronađena info tablica!
#   Obrađujem nesreću 17/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Aria_Air_Flight_1525
#     Pronađena info tablica!
#   Obrađujem nesreću 18/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Merpati_Nusantara_Airlines_Flight_9760
#     Pronađena info tablica!
#   Obrađujem nesreću 19/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Bangkok_Airways_Flight_266
#     Pronađena info tablica!
#   Obrađujem nesreću 20/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Airlines_PNG_Flight_4684
#     Pronađena info tablica!
#   Obrađujem nesreću 21/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Aerom%C3%A9xico_Flight_576
#     Pronađena info tablica!
#   Obrađujem nesreću 22/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Airlink_Flight_8911
#     Pronađena info tablica!
#   Obrađujem nesreću 23/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Northwest_Airlines_Flight_188
#     Pronađena info tablica!
#   Obrađujem nesreću 24/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Azza_Transport_Flight_2241
#     Pronađena info tablica!
#   Obrađujem nesreću 25/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Divi_Divi_Air_Flight_014
#     Pronađena info tablica!
#   Obrađujem nesreću 26/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/RwandAir_Flight_205
#     Pronađena info tablica!
#   Obrađujem nesreću 27/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2009_Pel-Air_Westwind_ditching
#     Pronađena info tablica!
#   Obrađujem nesreću 28/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Avient_Aviation_Flight_324
#     Pronađena info tablica!
#   Obrađujem nesreću 29/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/American_Airlines_Flight_331
#     Pronađena info tablica!
#   Obrađujem nesreću 30/30
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Northwest_Airlines_Flight_253
#     Pronađena info tablica!
#
# Obrađujem godinu 2008 (18/25)...
# Pronađeno 20 nesreća za godinu 2008
#   Obrađujem nesreću 1/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2008_Los_Roques_archipelago_Transaven_Let_L-410_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 2/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/British_Airways_Flight_38
#     Pronađena info tablica!
#   Obrađujem nesreću 3/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Lloyd_A%C3%A9reo_Boliviano_Flight_301
#     Pronađena info tablica!
#   Obrađujem nesreću 4/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Eagle_Airways_Flight_2279
#     Pronađena info tablica!
#   Obrađujem nesreću 5/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Belavia_Flight_1834
#     Pronađena info tablica!
#   Obrađujem nesreću 6/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Santa_B%C3%A1rbara_Airlines_Flight_518
#     Pronađena info tablica!
#   Obrađujem nesreću 7/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2008_Blue_Wing_Airlines_An-28_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 8/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Kata_Air_Transport_Flight_007
#     Pronađena info tablica!
#   Obrađujem nesreću 9/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Hewa_Bora_Airways_Flight_122
#     Pronađena info tablica!
#   Obrađujem nesreću 10/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Kalitta_Air_Flight_207
#     Pronađena info tablica!
#   Obrađujem nesreću 11/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Moskovia_Airlines_Flight_9675
#     Pronađena info tablica!
#   Obrađujem nesreću 12/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/TACA_Flight_390
#     Pronađena info tablica!
#   Obrađujem nesreću 13/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Sudan_Airways_Flight_109
#     Pronađena info tablica!
#   Obrađujem nesreću 14/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/USA_Jet_Airlines_Flight_199
#     Pronađena info tablica!
#   Obrađujem nesreću 15/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Centurion_Air_Cargo_Flight_164
#     Pronađena info tablica!
#   Obrađujem nesreću 16/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Qantas_Flight_30
#     Pronađena info tablica!
#   Obrađujem nesreću 17/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/East_Coast_Jets_Flight_81
#     Pronađena info tablica!
#   Obrađujem nesreću 18/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Spanair_Flight_5022
#     Pronađena info tablica!
#   Obrađujem nesreću 19/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2008_A%C3%A9reo_Ruta_Maya_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 20/20
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Iran_Aseman_Airlines_Flight_6895
#     Pronađena info tablica!
#
# Obrađujem godinu 2007 (19/25)...
# Pronađeno 13 nesreća za godinu 2007
#   Obrađujem nesreću 1/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Adam_Air_Flight_574
#     Pronađena info tablica!
#   Obrađujem nesreću 2/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2007_Balad_aircraft_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 3/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_West_Flight_612
#     Pronađena info tablica!
#   Obrađujem nesreću 4/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/R%C3%A9gional_Flight_7775
#     Pronađena info tablica!
#   Obrađujem nesreću 5/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Adam_Air_Flight_172
#     Pronađena info tablica!
#   Obrađujem nesreću 6/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Garuda_Indonesia_Flight_200
#     Pronađena info tablica!
#   Obrađujem nesreću 7/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/UTair_Flight_471
#     Pronađena info tablica!
#   Obrađujem nesreću 8/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2007_Mogadishu_TransAVIAexport_Airlines_Il-76_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 9/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Kenya_Airways_Flight_507
#     Pronađena info tablica!
#   Obrađujem nesreću 10/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2007_San_Francisco_International_Airport_runway_incursion
#     Pronađena info tablica!
#   Obrađujem nesreću 11/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2007_Paramount_Airlines_Mil_Mi-8_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 12/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2007_Free_Airlines_L-410_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 13/13
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/PMTair_Flight_241
#     Pronađena info tablica!
#
# Obrađujem godinu 2006 (20/25)...
# Pronađeno 15 nesreća za godinu 2006
#   Obrađujem nesreću 1/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/TEAM_Linhas_A%C3%A9reas_Flight_6865
#     Pronađena info tablica!
#   Obrađujem nesreću 2/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Armavia_Flight_967
#     Pronađena info tablica!
#   Obrađujem nesreću 3/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2006_Yeti_Airlines_Twin_Otter_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 4/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/S7_Airlines_Flight_778
#     Pronađena info tablica!
#   Obrađujem nesreću 5/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/PIA_Flight_688
#     Pronađena info tablica!
#   Obrađujem nesreću 6/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2006_O%27Hare_International_Airport_runway_incursion
#     Pronađena info tablica!
#   Obrađujem nesreću 7/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/FedEx_Express_Flight_630
#     Pronađena info tablica!
#   Obrađujem nesreću 8/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_Alg%C3%A9rie_Flight_2208
#     Pronađena info tablica!
#   Obrađujem nesreću 9/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Pulkovo_Aviation_Enterprise_Flight_612
#     Pronađena info tablica!
#   Obrađujem nesreću 10/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Comair_Flight_5191
#     Pronađena info tablica!
#   Obrađujem nesreću 11/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Iran_Airtour_Flight_945
#     Pronađena info tablica!
#   Obrađujem nesreću 12/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/EasyJet_Flight_6074
#     Pronađena info tablica!
#   Obrađujem nesreću 13/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2006_Shree_Air_Mil_Mi-8_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 14/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Gol_Transportes_A%C3%A9reos_Flight_1907
#     Pronađena info tablica!
#   Obrađujem nesreću 15/15
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Turkish_Airlines_Flight_1476
#     Pronađena info tablica!
#
# Obrađujem godinu 2005 (21/25)...
# Pronađeno 22 nesreća za godinu 2005
#   Obrađujem nesreću 1/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Kam_Air_Flight_904
#     Pronađena info tablica!
#   Obrađujem nesreću 2/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/British_Airways_Flight_268
#     Pronađena info tablica!
#   Obrađujem nesreću 3/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_Transat_Flight_961
#     Pronađena info tablica!
#   Obrađujem nesreću 4/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Regional_Airlines_Flight_9288
#     Pronađena info tablica!
#   Obrađujem nesreću 5/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/West_Caribbean_Airways_Flight_9955
#     Pronađena info tablica!
#   Obrađujem nesreću 6/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Airwork_Flight_23
#     Pronađena info tablica!
#   Obrađujem nesreću 7/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Lockhart_River_air_disaster
#     Pronađena info tablica!
#   Obrađujem nesreću 8/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2005_Logan_Airport_runway_incursion
#     Pronađena info tablica!
#   Obrađujem nesreću 9/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2005_Equatorial_Express_Airlines_An-24_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 10/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_France_Flight_358
#     Pronađena info tablica!
#   Obrađujem nesreću 11/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Tuninter_Flight_1153
#     Pronađena info tablica!
#   Obrađujem nesreću 12/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Copterline_Flight_103
#     Pronađena info tablica!
#   Obrađujem nesreću 13/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Helios_Airways_Flight_522
#     Pronađena info tablica!
#   Obrađujem nesreću 14/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/West_Caribbean_Airways_Flight_708
#     Pronađena info tablica!
#   Obrađujem nesreću 15/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/TANS_Per%C3%BA_Flight_204
#     Pronađena info tablica!
#   Obrađujem nesreću 16/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Mandala_Airlines_Flight_091
#     Pronađena info tablica!
#   Obrađujem nesreću 17/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/JetBlue_Flight_292
#     Pronađena info tablica!
#   Obrađujem nesreću 18/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Bellview_Airlines_Flight_210
#     Pronađena info tablica!
#   Obrađujem nesreću 19/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Southwest_Airlines_Flight_1248
#     Pronađena info tablica!
#   Obrađujem nesreću 20/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Sosoliso_Airlines_Flight_1145
#     Pronađena info tablica!
#   Obrađujem nesreću 21/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Chalk%27s_Ocean_Airways_Flight_101
#     Pronađena info tablica!
#   Obrađujem nesreću 22/22
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Azerbaijan_Airlines_Flight_217
#     Pronađena info tablica!
#
# Obrađujem godinu 2004 (22/25)...
# Pronađeno 14 nesreća za godinu 2004
#   Obrađujem nesreću 1/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Flash_Airlines_Flight_604
#     Pronađena info tablica!
#   Obrađujem nesreću 2/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Uzbekistan_Airways_Flight_1154
#     Pronađena info tablica!
#   Obrađujem nesreću 3/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Kish_Air_Flight_7170
#     Pronađena info tablica!
#   Obrađujem nesreću 4/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Rico_Linhas_A%C3%A9reas_Flight_4815
#     Pronađena info tablica!
#   Obrađujem nesreću 5/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Gabon_Express_Flight_221
#     Pronađena info tablica!
#   Obrađujem nesreću 6/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_Tahoma_Flight_185
#     Pronađena info tablica!
#   Obrađujem nesreću 7/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2004_Russian_aircraft_bombings
#     Pronađena info tablica!
#   Obrađujem nesreću 8/14
#   Obrađujem nesreću 9/14
#   Obrađujem nesreću 10/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/MK_Airlines_Flight_1602
#     Pronađena info tablica!
#   Obrađujem nesreću 11/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Pinnacle_Airlines_Flight_3701
#     Pronađena info tablica!
#   Obrađujem nesreću 12/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Corporate_Airlines_Flight_5966
#     Pronađena info tablica!
#   Obrađujem nesreću 13/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/China_Eastern_Airlines_Flight_5210
#     Pronađena info tablica!
#   Obrađujem nesreću 14/14
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Lion_Air_Flight_538
#     Pronađena info tablica!
#
# Obrađujem godinu 2003 (23/25)...
# Pronađeno 16 nesreća za godinu 2003
#   Obrađujem nesreću 1/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_Midwest_Flight_5481
#     Pronađena info tablica!
#   Obrađujem nesreću 2/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Turkish_Airlines_Flight_634
#     Pronađena info tablica!
#   Obrađujem nesreću 3/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/TANS_Per%C3%BA_Flight_222
#     Pronađena info tablica!
#   Obrađujem nesreću 4/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_Alg%C3%A9rie_Flight_6289
#     Pronađena info tablica!
#   Obrađujem nesreću 5/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_China_Flight_112
#     Pronađena info tablica!
#   Obrađujem nesreću 6/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2003_Congo_air_disaster
#     Pronađena info tablica!
#   Obrađujem nesreću 7/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2003_Angola_Boeing_727_disappearance
#     Pronađena info tablica!
#   Obrađujem nesreću 8/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/UM_Airlines_Flight_4230
#     Pronađena info tablica!
#   Obrađujem nesreću 9/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Qantas_Flight_1737
#     Pronađena info tablica!
#   Obrađujem nesreću 10/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_France_Flight_5672
#     Pronađena info tablica!
#   Obrađujem nesreću 11/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Sudan_Airways_Flight_139
#     Pronađena info tablica!
#   Obrađujem nesreću 12/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Tropical_Airways_Flight_1301
#     Pronađena info tablica!
#   Obrađujem nesreću 13/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Colgan_Air_Flight_9446
#     Pronađena info tablica!
#   Obrađujem nesreću 14/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2003_Baghdad_DHL_attempted_shootdown_incident
#     Pronađena info tablica!
#   Obrađujem nesreću 15/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/FedEx_Express_Flight_647
#     Pronađena info tablica!
#   Obrađujem nesreću 16/16
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/UTA_Flight_141
#     Pronađena info tablica!
#
# Obrađujem godinu 2002 (24/25)...
# Pronađeno 9 nesreća za godinu 2002
#   Obrađujem nesreću 1/9
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Siberia_Airlines_Flight_852
#     Pronađena info tablica!
#   Obrađujem nesreću 2/9
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Garuda_Indonesia_Flight_421
#     Pronađena info tablica!
#   Obrađujem nesreću 3/9
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/TAME_Flight_120
#     Pronađena info tablica!
#   Obrađujem nesreću 4/9
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Iran_Air_Tours_Flight_956
#     Pronađena info tablica!
#   Obrađujem nesreću 5/9
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_China_Flight_129
#     Pronađena info tablica!
#   Obrađujem nesreću 6/9
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/EAS_Airlines_Flight_4226
#     Pronađena info tablica!
#   Obrađujem nesreću 7/9
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/EgyptAir_Flight_843
#     Pronađena info tablica!
#   Obrađujem nesreću 8/9
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/China_Northern_Airlines_Flight_6136
#     Pronađena info tablica!
#   Obrađujem nesreću 9/9
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/China_Airlines_Flight_611
#     Pronađena info tablica!
#
# Obrađujem godinu 2001 (25/25)...
# Pronađeno 25 nesreća za godinu 2001
#   Obrađujem nesreću 1/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Yemenia_Flight_448
#     Pronađena info tablica!
#   Obrađujem nesreću 2/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/RUTACA_Airlines_Flight_225
#     Pronađena info tablica!
#   Obrađujem nesreću 3/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2001_Japan_Airlines_mid-air_incident
#     Pronađena info tablica!
#   Obrađujem nesreću 4/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Iberia_Flight_1456
#     Pronađena info tablica!
#   Obrađujem nesreću 5/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Loganair_Flight_670A
#     Pronađena info tablica!
#   Obrađujem nesreću 6/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Thai_Airways_International_Flight_114
#     Pronađena info tablica!
#   Obrađujem nesreću 7/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_Cara%C3%AFbes_Flight_1501
#     Pronađena info tablica!
#   Obrađujem nesreću 8/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2001_Avjet_Aspen_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 9/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2001_Faraz_Qeshm_Airlines_Yak-40_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 10/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Vladivostok_Air_Flight_352
#     Pronađena info tablica!
#   Obrađujem nesreću 11/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Rus_Flight_9633
#     Pronađena info tablica!
#   Obrađujem nesreću 12/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Air_Transat_Flight_236
#     Pronađena info tablica!
#   Obrađujem nesreću 13/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2001_Marsh_Harbour_Cessna_402_crash
#     Pronađena info tablica!
#   Obrađujem nesreću 14/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Binter_Mediterr%C3%A1neo_Flight_8261
#     Pronađena info tablica!
#   Obrađujem nesreću 15/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/September_11_attacks
#     Pronađena info tablica!
#   Obrađujem nesreću 16/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/American_Airlines_Flight_11
#     Pronađena info tablica!
#   Obrađujem nesreću 17/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/United_Airlines_Flight_175
#     Pronađena info tablica!
#   Obrađujem nesreću 18/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/American_Airlines_Flight_77
#     Pronađena info tablica!
#   Obrađujem nesreću 19/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/United_Airlines_Flight_93
#     Pronađena info tablica!
#   Obrađujem nesreću 20/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Korean_Air_Flight_085
#     Pronađena info tablica!
#   Obrađujem nesreću 21/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Delta_Air_Lines_Flight_1989
#     Pronađena info tablica!
#   Obrađujem nesreću 22/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/TAM_Flight_9755
#     Pronađena info tablica!
#   Obrađujem nesreću 23/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Aeroflot_Flight_521
#     Pronađena info tablica!
#   Obrađujem nesreću 24/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/Siberia_Airlines_Flight_1812
#     Pronađena info tablica!
#   Obrađujem nesreću 25/25
#     Dohvaćam detalje sa: https://en.wikipedia.org/wiki/2001_Linate_Airport_runway_collision
#     Pronađena info tablica!
#
# Statistika popunjenosti aircraft_type: 321/321 (100.0%)
#
# Podaci uspješno spremljeni u aircraft_accidents.xlsx
# Podaci uspješno spremljeni u aircraft_accidents.csv
# Preuzimam Excel datoteku aircraft_accidents.xlsx...
# Preuzimam CSV datoteku aircraft_accidents.csv...
# Prvih 10 redova prikupljenih podataka:
#    year                           date  \
# 0  2025    28 January 2025 (2025-1-28)
# 1  2025    29 January 2025 (2025-1-29)
# 2  2025  January 29, 2025 (2025-01-29)
# 3  2025  February 6, 2025 (2025-02-06)
# 4  2025  February 17, 2025 (2025-2-17)
# 5  2025     17 March 2025 (2025-03-17)
# 6  2025     22 March 2025 (2025-03-22)
# 7  2024      2 January 2024 (2024-1-2)
# 8  2024   January 5, 2024 (2024-01-05)
# 9  2024   23 January 2024 (2024-01-23)
#
#                                             location  \
# 0  Gimhae International Airport, Busan, South Kor...
# 1  Near GPOC Unity Airstrip, Rubkona County, Unit...
# 2  Potomac River, Washington, D.C., U.S. 38°50′33...
# 3  Over the Norton Sound, Bering Sea 64°21′0″N 16...
# 4  Toronto Pearson International Airport, Mississ...
# 5  near Juan Manuel Gálvez International Airport,...
# 6  Ceel Xabaaloow, 24 km (15 mi) southwest of Mog...
# 7  Runway 34R, Haneda Airport, Tokyo, Japan 35°32...
# 8  In-air; near Portland, Oregon, United States 4...
# 9  near Fort Smith Airport, Fort Smith, Northwest...
#
#                                 aircraft_type  \
# 0                             Airbus A321-231
# 1                            Beechcraft 1900D
# 2                  Sikorsky UH-60L Black Hawk
# 3                Cessna 208B Grand Caravan EX
# 4                         Bombardier CRJ900LR
# 5              British Aerospace Jetstream 32
# 6          De Havilland Canada DHC-5D Buffalo
# 7  De Havilland Canada DHC-8-315Q MPA[Note 1]
# 8                            Boeing 737 MAX 9
# 9              British Aerospace Jetstream 32
#
#                                       operator  \
# 0                                    Air Busan
# 1    Eagle Air on behalf of Light Air Services
# 2  12th Aviation Battalion, United States Army
# 3                                   Bering Air
# 4          Endeavor Air as Delta Connection[a]
# 5                             Aerolínea Lanhsa
# 6                             Trident Aviation
# 7                            Japan Coast Guard
# 8                              Alaska Airlines
# 9                             Northwestern Air
#
#                                        flight_origin registration  \
# 0   Gimhae International Airport, Busan, South Korea       HL7763
# 1  GPOC Unity Airstrip, Rubkona County, Unity Sta...       5X-RHB
# 2  Davison Army Airfield, Fort Belvoir, Virginia,...  00-26860[5]
# 3          Unalakleet Airport, Alaska, United States       N321BA
# 4  Minneapolis–Saint Paul International Airport, ...       N932XJ
# 5  Juan Manuel Gálvez International Airport, Roat...       HR-AYW
# 6                    Dhobley Airport (HCDB), Somalia       5Y-RBA
# 7                       Haneda Airport, Tokyo, Japan       JA722A
# 8  Portland International Airport, Portland, Oreg...    N704AL[1]
# 9                                 Fort Smith Airport       C-FNAA
#
#                                          destination passengers crew  \
# 0     Hong Kong International Airport, Hong Kong SAR        169    7
# 1      Juba International Airport, Juba, South Sudan         19    2
# 2  Davison Army Airfield, Fort Belvoir, Virginia,...         60    3
# 3                Nome Airport, Alaska, United States          9    1
# 4  Toronto Pearson International Airport, Mississ...         76    4
# 5  Golosón International Airport, La Ceiba, Honduras         15    3
# 6           Aden Adde International Airport, Somalia       None    5
# 7                    Niigata Airport, Niigata, Japan        367    6
# 8  Ontario International Airport, Ontario, Califo...        171    6
# 9                        Diavik Diamond Mine Airport          5    2
#
#   occupants injuries fatalities survivors missing  \
# 0       176        7          0       176    None
# 1        21        1         20         1    None
# 2         3     None          3         0    None
# 3        10     None         10         0    None
# 4        80       21          0        80    None
# 5        18        5         13         5    None
# 6         5     None          5         0    None
# 7         6        1          5         1    None
# 8       177        3          0       177    None
# 9         7        1          6         1    None
#
#                                              summary
# 0    Ground fire before takeoff, under investigation
# 1         Crashed after takeoff, under investigation
# 2             Mid-air collision, under investigation
# 3              Crashed into ice, under investigation
# 4  Crashed upon landing, overturned on the runway...
# 5  Possible engine failure; runway excursion on t...
# 6  Crashed after possible engine failure; under i...
# 7                                   Runway collision
# 8  Uncontrolled decompression after loss of incor...
# 9        Collision with terrain, under investigation

# %% [markdown]
# ##Cleaning Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/Analiza_mreza/aircraft_accidents-2.csv')

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import re

# %%
# Učitavanje podataka
df = pd.read_csv('aircraft_accidents.csv', encoding='utf-8')

# Prikaz početnih informacija o podacima
print("Dimenzije izvornog skupa podataka:", df.shape)
print("Broj praznih vrijednosti po stupcima:")
print(df.isnull().sum())
print("\nPregled tipova podataka:")
print(df.dtypes)
# Out:
# Dimenzije izvornog skupa podataka: (321, 16)
# Broj praznih vrijednosti po stupcima:
# year               0
# date               2
# location           2
# aircraft_type      0
# operator           0
# flight_origin      8
# registration       5
# destination        9
# passengers        24
# crew               5
# occupants         29
# injuries         158
# fatalities         6
# survivors          6
# missing          319
# summary            4
# dtype: int64
#
# Pregled tipova podataka:
# year               int64
# date              object
# location          object
# aircraft_type     object
# operator          object
# flight_origin     object
# registration      object
# destination       object
# passengers        object
# crew              object
# occupants         object
# injuries          object
# fatalities        object
# survivors         object
# missing          float64
# summary           object
# dtype: object

# %%
df.head()
# Out:
#    year                           date  \
# 0  2025    28 January 2025 (2025-1-28)
# 1  2025    29 January 2025 (2025-1-29)
# 2  2025  January 29, 2025 (2025-01-29)
# 3  2025  February 6, 2025 (2025-02-06)
# 4  2025  February 17, 2025 (2025-2-17)
#
#                                             location  \
# 0  Gimhae International Airport, Busan, South Kor...
# 1  Near GPOC Unity Airstrip, Rubkona County, Unit...
# 2  Potomac River, Washington, D.C., U.S. 38°50′33...
# 3  Over the Norton Sound, Bering Sea 64°21′0″N 16...
# 4  Toronto Pearson International Airport, Mississ...
#
#                   aircraft_type                                     operator  \
# 0               Airbus A321-231                                    Air Busan
# 1              Beechcraft 1900D    Eagle Air on behalf of Light Air Services
# 2    Sikorsky UH-60L Black Hawk  12th Aviation Battalion, United States Army
# 3  Cessna 208B Grand Caravan EX                                   Bering Air
# 4           Bombardier CRJ900LR          Endeavor Air as Delta Connection[a]
#
#                                        flight_origin registration  \
# 0   Gimhae International Airport, Busan, South Korea       HL7763
# 1  GPOC Unity Airstrip, Rubkona County, Unity Sta...       5X-RHB
# 2  Davison Army Airfield, Fort Belvoir, Virginia,...  00-26860[5]
# 3          Unalakleet Airport, Alaska, United States       N321BA
# 4  Minneapolis–Saint Paul International Airport, ...       N932XJ
#
#                                          destination passengers crew  \
# 0     Hong Kong International Airport, Hong Kong SAR        169    7
# 1      Juba International Airport, Juba, South Sudan         19    2
# 2  Davison Army Airfield, Fort Belvoir, Virginia,...         60    3
# 3                Nome Airport, Alaska, United States          9    1
# 4  Toronto Pearson International Airport, Mississ...         76    4
#
#   occupants injuries fatalities survivors  missing  \
# 0       176        7          0       176      NaN
# 1        21        1         20         1      NaN
# 2         3      NaN          3         0      NaN
# 3        10      NaN         10         0      NaN
# 4        80       21          0        80      NaN
#
#                                              summary
# 0    Ground fire before takeoff, under investigation
# 1         Crashed after takeoff, under investigation
# 2             Mid-air collision, under investigation
# 3              Crashed into ice, under investigation
# 4  Crashed upon landing, overturned on the runway...

# %%
# !pip install neo4j
# Out:
# Collecting neo4j
#   Downloading neo4j-5.28.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from neo4j) (2025.1)
# Downloading neo4j-5.28.1-py3-none-any.whl (312 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.3/312.3 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: neo4j
# Successfully installed neo4j-5.28.1

# %%
from neo4j import GraphDatabase

URI = "bolt://44.203.174.63:7687"
AUTH = ("neo4j", "expenditure-scab-grain")

try:
    driver = GraphDatabase.driver(URI, auth=AUTH)
    with driver.session() as session:
        result = session.run("RETURN 'Connection Successful!' AS message")
        print(result.single()["message"])
except Exception as e:
    print(f"Error connecting to Neo4j: {e}")
# Out:
# Connection Successful!

# %%
df.columns
# Out:
# Index(['year', 'date', 'location', 'aircraft_type', 'operator',
#        'flight_origin', 'registration', 'destination', 'passengers', 'crew',
#        'occupants', 'injuries', 'fatalities', 'survivors', 'missing',
#        'summary'],
#       dtype='object')
